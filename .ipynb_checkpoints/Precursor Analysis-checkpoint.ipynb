# %% [markdown]
# # Precursor Analysis

# %% [raw]
# This is simply some precursor analysis on the given NYSE Kaggle data. The goal is to mine information such that
# a portfolio can be constructed. Pairs trading clustering analysis is also a goal of this project.

# %%
#Fundamental data contains the ticker, a given period, and many fundamenatal financial metrics for that period
fundamentalData <- read.csv('nyse/fundamentals.csv')

# %%
#Figure out what are the basket of companies we are looking at and their various sectors
uniqueTickers <- unique(fundamentalData$Ticker.Symbol)
securitiesData <- read.csv('nyse/securities.csv')

# %%
#Sector Representation in Data
prop.table(table(securitiesData$GICS.Sector))
# Out:
#      Consumer Discretionary            Consumer Staples
#                  0.16831683                  0.07326733
#                      Energy                  Financials
#                  0.07128713                  0.12673267
#                 Health Care                 Industrials
#                  0.11683168                  0.13663366
#      Information Technology                   Materials
#                  0.13465347                  0.04950495
#                 Real Estate Telecommunications Services
#                  0.05742574                  0.00990099
#                   Utilities
#                  0.05544554

# %% [markdown]
# # Analyzing Cash Ratios in various sectors

# %%
sector <- function(ticker){
    return(securitiesData[which(securitiesData$Ticker.symbol == ticker), ][4][1,])
}
#Cash Ratios for IT Companies
#Duplicate companies across many periods ARE included
sectors <- lapply(X = as.vector(fundamentalData$Ticker.Symbol), FUN = sector)
fundamentalData['sector'] = as.vector(unlist(sectors))

# %%
install.packages('ggplot2')
install.packages('reshape2')
# Out:
# The downloaded binary packages are in
# 	/var/folders/7d/8fqmvyg97bq8k_c4rssxnrzh0000gn/T//RtmpVSd5cn/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/7d/8fqmvyg97bq8k_c4rssxnrzh0000gn/T//RtmpVSd5cn/downloaded_packages

# %%
healthCareData <- na.omit(fundamentalData[which(fundamentalData['sector'] == 'Health Care'),]$Cash.Ratio)
hist(healthCareData, main = "Health Care Cash Ratios")


financialData <- na.omit(fundamentalData[which(fundamentalData['sector'] == 'Financials'),]$Cash.Ratio)
hist(financialData, main = "Finance CR")




realEstate <- na.omit(fundamentalData[which(fundamentalData['sector'] == 'Real Estate'),]$Cash.Ratio)
hist(financialData, main = "Real Estate CR")

Industrials <- na.omit(fundamentalData[which(fundamentalData['sector'] == 'Industrials'),]$Cash.Ratio)
hist(financialData, main = "Industrials CR")


consumerDiscretionary <- na.omit(fundamentalData[which(fundamentalData['sector'] == 'Consumer Discretionary'),]$Cash.Ratio)
hist(financialData, main = "Consumer Discretionary")
# Out:
# Plot with title “Health Care Cash Ratios”
# Plot with title “Finance CR”
# Plot with title “Real Estate CR”
# Plot with title “Industrials CR”
# Plot with title “Consumer Discretionary”

# %%
itCashRatios <- fundamentalData[which(fundamentalData['sector'] == "Information Technology"),]$Cash.Ratio
hist(itCashRatios, main = 'Distribution of Cash Ratios in IT')
# Out:
# Plot with title “Distribution of Cash Ratios in IT”

# %%
#Ok so it looks like the distribution of the cash ratios are pretty similar across these sectors.

# %% [markdown]
# # Time Series Analysis of Various IT Companies

# %%
stockPriceData <- read.csv('nyse/prices-split-adjusted.csv')

# %%
stockPriceData$date = as.Date(stockPriceData$date, format = "%Y-%m-%d")

# %%
plot.ts(stockPriceData[which(stockPriceData$symbol == 'AAPL'),])
# Out:
# plot without title

# %%
healthCareTickers <- securitiesData[which(securitiesData$GICS.Sector == 'Health Care'), ]$Ticker.symbol
financeTickers <- securitiesData[which(securitiesData$GICS.Sector == 'Financials'), ]$Ticker.symbol
techTickers <- securitiesData[which(securitiesData$GICS.Sector == "Information Technology"), ]$Ticker.symbol

# %%
healthcareStocks <- stockPriceData[which(stockPriceData$symbol %in% healthCareTickers), ]
healthcareStocksAgg <- aggregate(. ~ date, data = healthcareStocks, mean)

techStocks <- stockPriceData[which(stockPriceData$symbol %in% techTickers),]
techStocksAgg <- aggregate(. ~ date, data = techStocks, mean)

financeStocks <- stockPriceData[which(stockPriceData$symbol %in% financeTickers), ]
financeStocksAgg <- aggregate(. ~ date, data = financeStocks, mean)

# %%
plot.ts(techStocksAgg$close, main = 'Aggregated Tech Closing Prices')
plot.ts(financeStocksAgg$close, main = 'Aggregated Financials Closing Prices')
plot.ts(healthcareStocksAgg$close, main = 'Aggregated Healthcare Closing Prices')
# Out:
# Plot with title “Aggregated Tech Closing Prices”
# Plot with title “Aggregated Financials Closing Prices”
# Plot with title “Aggregated Healthcare Closing Prices”

# %%
?cor

# %%
#Financials and tech Look pretty correlated
#lets just calculate the correlation of closing prices in recent years vs overall
cor(x = financeStocksAgg$close, y = techStocksAgg$close, use = "everything",
    method = c("pearson", "kendall", "spearman"))
# Out:
# [1] 0.9609117
